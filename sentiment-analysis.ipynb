# %%
import pandas as pd

books = pd.read_csv("books_with_categories.csv")

# %%
from transformers import pipeline
classifier = pipeline("text-classification", model="./emotion-english-distilroberta-base", top_k=None, device=-1)

classifier("I love this!")
# Out:
# [[{'label': 'joy', 'score': 0.9771687984466553},
#   {'label': 'surprise', 'score': 0.00852869637310505},
#   {'label': 'neutral', 'score': 0.005764597561210394},
#   {'label': 'anger', 'score': 0.004419798497110605},
#   {'label': 'sadness', 'score': 0.002092392183840275},
#   {'label': 'disgust', 'score': 0.0016119939973577857},
#   {'label': 'fear', 'score': 0.00041385297663509846}]]

# %%
books["description"][0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.'

# %%
classifier(books["description"][0])
# Out:
# [[{'label': 'fear', 'score': 0.6548407673835754},
#   {'label': 'neutral', 'score': 0.16985219717025757},
#   {'label': 'sadness', 'score': 0.11640915274620056},
#   {'label': 'surprise', 'score': 0.020700691267848015},
#   {'label': 'disgust', 'score': 0.01910068467259407},
#   {'label': 'joy', 'score': 0.015161365270614624},
#   {'label': 'anger', 'score': 0.003935147542506456}]]

# %%
classifier(books["description"][0].split("."))
# Out:
# [[{'label': 'surprise', 'score': 0.7296027541160583},
#   {'label': 'neutral', 'score': 0.14038535952568054},
#   {'label': 'fear', 'score': 0.06816219538450241},
#   {'label': 'joy', 'score': 0.047942645847797394},
#   {'label': 'anger', 'score': 0.009156349115073681},
#   {'label': 'disgust', 'score': 0.002628469141200185},
#   {'label': 'sadness', 'score': 0.002122161677107215}],
#  [{'label': 'neutral', 'score': 0.44937077164649963},
#   {'label': 'disgust', 'score': 0.2735905647277832},
#   {'label': 'joy', 'score': 0.10908355563879013},
#   {'label': 'sadness', 'score': 0.09362763911485672},
#   {'label': 'anger', 'score': 0.04047827050089836},
#   {'label': 'surprise', 'score': 0.02697017788887024},
#   {'label': 'fear', 'score': 0.006879054941236973}],
#  [{'label': 'neutral', 'score': 0.6462151408195496},
#   {'label': 'sadness', 'score': 0.24273420870304108},
#   {'label': 'disgust', 'score': 0.04342268407344818},
#   {'label': 'surprise', 'score': 0.028300534933805466},
#   {'label': 'joy', 'score': 0.01421146560460329},
#   {'label': 'fear', 'score': 0.014084088616073132},
#   {'label': 'anger', 'score': 0.011031893081963062}],
#  [{'label': 'fear', 'score': 0.9281689524650574},
#   {'label': 'anger', 'score': 0.03219056501984596},
#   {'label': 'neutral', 'score': 0.01280857715755701},
#   {'label': 'sadness', 'score': 0.008756806142628193},
#   {'label': 'surprise', 'score': 0.00859783310443163},
#   {'label': 'disgust', 'score': 0.008431728929281235},
#   {'label': 'joy', 'score': 0.001045580138452351}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104142017662525},
#   {'label': 'disgust', 'score': 0.006480592768639326},
#   {'label': 'fear', 'score': 0.005393985193222761},
#   {'label': 'surprise', 'score': 0.0022869398817420006},
#   {'label': 'anger', 'score': 0.0018428885377943516},
#   {'label': 'joy', 'score': 0.0017338772304356098}],
#  [{'label': 'joy', 'score': 0.9327978491783142},
#   {'label': 'disgust', 'score': 0.03771726414561272},
#   {'label': 'neutral', 'score': 0.015891851857304573},
#   {'label': 'sadness', 'score': 0.006444528698921204},
#   {'label': 'anger', 'score': 0.005024985875934362},
#   {'label': 'surprise', 'score': 0.0015812076162546873},
#   {'label': 'fear', 'score': 0.0005423073307611048}],
#  [{'label': 'joy', 'score': 0.6528704762458801},
#   {'label': 'neutral', 'score': 0.25427499413490295},
#   {'label': 'surprise', 'score': 0.06808297336101532},
#   {'label': 'sadness', 'score': 0.009908990003168583},
#   {'label': 'disgust', 'score': 0.006512222811579704},
#   {'label': 'anger', 'score': 0.004821304231882095},
#   {'label': 'fear', 'score': 0.003529011970385909}],
#  [{'label': 'neutral', 'score': 0.5494755506515503},
#   {'label': 'sadness', 'score': 0.11169032752513885},
#   {'label': 'disgust', 'score': 0.10400693863630295},
#   {'label': 'surprise', 'score': 0.07876572012901306},
#   {'label': 'anger', 'score': 0.06413385272026062},
#   {'label': 'fear', 'score': 0.05136300250887871},
#   {'label': 'joy', 'score': 0.04056461527943611}]]

# %%
sentences = books["description"][0].split(".")
predictions = classifier(sentences)

# %%
sentences[0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives'

# %%
predictions[0]
# Out:
# [{'label': 'surprise', 'score': 0.7296027541160583},
#  {'label': 'neutral', 'score': 0.14038535952568054},
#  {'label': 'fear', 'score': 0.06816219538450241},
#  {'label': 'joy', 'score': 0.047942645847797394},
#  {'label': 'anger', 'score': 0.009156349115073681},
#  {'label': 'disgust', 'score': 0.002628469141200185},
#  {'label': 'sadness', 'score': 0.002122161677107215}]

# %%
sorted(predictions[0], key=lambda x: x["label"])
# Out:
# [{'label': 'anger', 'score': 0.009156349115073681},
#  {'label': 'disgust', 'score': 0.002628469141200185},
#  {'label': 'fear', 'score': 0.06816219538450241},
#  {'label': 'joy', 'score': 0.047942645847797394},
#  {'label': 'neutral', 'score': 0.14038535952568054},
#  {'label': 'sadness', 'score': 0.002122161677107215},
#  {'label': 'surprise', 'score': 0.7296027541160583}]

# %%
import numpy as np

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []

emotion_scores = {label: [] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
    per_emotion_scores = {label: [] for label in emotion_labels}
    for prediction in predictions:
        sorted_predictions = sorted(prediction, key=lambda x: x["label"])
        for index, label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_predictions[index]['score'])
    return {label: np.max(scores) for label, scores in per_emotion_scores.items()}

# %%
for i in range(10):
    isbn.append(books["isbn13"][i])
    sentences = books['description'][i].split('.')
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])

# %%
emotion_scores
# Out:
# {'anger': [0.06413385272026062,
#   0.6126176118850708,
#   0.06413385272026062,
#   0.35148343443870544,
#   0.08141231536865234,
#   0.23222483694553375,
#   0.5381848812103271,
#   0.06413385272026062,
#   0.30066993832588196,
#   0.06413385272026062],
#  'disgust': [0.2735905647277832,
#   0.34828630089759827,
#   0.10400693863630295,
#   0.15072259306907654,
#   0.1844954937696457,
#   0.7271748185157776,
#   0.15585486590862274,
#   0.10400693863630295,
#   0.27948158979415894,
#   0.1779261827468872],
#  'fear': [0.9281689524650574,
#   0.942527711391449,
#   0.9723207950592041,
#   0.3607062101364136,
#   0.09504342079162598,
#   0.05136300250887871,
#   0.7474266290664673,
#   0.4044981002807617,
#   0.9155241250991821,
#   0.05136300250887871],
#  'joy': [0.9327978491783142,
#   0.7044225931167603,
#   0.7672377824783325,
#   0.251881867647171,
#   0.04056461527943611,
#   0.04337583854794502,
#   0.8725652694702148,
#   0.04056461527943611,
#   0.04056461527943611,
#   0.04056461527943611],
#  'sadness': [0.6462151408195496,
#   0.8879395127296448,
#   0.5494755506515503,
#   0.7326856255531311,
#   0.8843896389007568,
#   0.6213923096656799,
#   0.7121937274932861,
#   0.5494755506515503,
#   0.840289294719696,
#   0.8603723645210266],
#  'surprise': [0.9671575427055359,
#   0.11169032752513885,
#   0.11169032752513885,
#   0.11169032752513885,
#   0.4758804440498352,
#   0.11169032752513885,
#   0.4079988896846771,
#   0.8202832937240601,
#   0.35445988178253174,
#   0.11169032752513885],
#  'neutral': [0.7296027541160583,
#   0.2525458037853241,
#   0.07876572012901306,
#   0.07876572012901306,
#   0.07876572012901306,
#   0.27190303802490234,
#   0.07876572012901306,
#   0.23448634147644043,
#   0.13561396300792694,
#   0.07876572012901306]}

# %%
from tqdm.notebook import tqdm

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books["isbn13"][i])
    sentences = books['description'][i].split('.')
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
#   0%|          | 0/5197 [00:00<?, ?it/s]

# %%
emotions_df = pd.DataFrame(emotion_scores)
emotions_df["isbn13"] = isbn

# %%
emotions_df
# Out:
#          anger   disgust      fear       joy   sadness  surprise   neutral  \
# 0     0.064134  0.273591  0.928169  0.932798  0.646215  0.967158  0.729603
# 1     0.612618  0.348286  0.942528  0.704423  0.887940  0.111690  0.252546
# 2     0.064134  0.104007  0.972321  0.767238  0.549476  0.111690  0.078766
# 3     0.351483  0.150723  0.360706  0.251882  0.732686  0.111690  0.078766
# 4     0.081412  0.184495  0.095043  0.040565  0.884390  0.475880  0.078766
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148209  0.030643  0.919165  0.255171  0.853721  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400263  0.883198  0.111690  0.227765
# 5194  0.009997  0.009929  0.339217  0.947779  0.375754  0.066685  0.057625
# 5195  0.064134  0.104007  0.459271  0.759456  0.951104  0.368111  0.078766
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078766
#
#              isbn13
# 0     9780002005883
# 1     9780002261982
# 2     9780006178736
# 3     9780006280897
# 4     9780006280934
# ...             ...
# 5192  9788172235222
# 5193  9788173031014
# 5194  9788179921623
# 5195  9788185300535
# 5196  9789027712059
#
# [5197 rows x 8 columns]

# %%
books = pd.merge(books, emotions_df, on="isbn13")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ...  \
# 0               3.85      247.0  ...
# 1               3.83      241.0  ...
# 2               3.93      512.0  ...
# 3               4.15      170.0  ...
# 4               4.09      176.0  ...
# ...              ...        ...  ...
# 5192            2.93      324.0  ...
# 5193            3.70      175.0  ...
# 5194            3.82      198.0  ...
# 5195            4.51      531.0  ...
# 5196            0.00      210.0  ...
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories  \
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...           Fiction
# 5193  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5194  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
#          anger   disgust      fear       joy   sadness  surprise   neutral
# 0     0.064134  0.273591  0.928169  0.932798  0.646215  0.967158  0.729603
# 1     0.612618  0.348286  0.942528  0.704423  0.887940  0.111690  0.252546
# 2     0.064134  0.104007  0.972321  0.767238  0.549476  0.111690  0.078766
# 3     0.351483  0.150723  0.360706  0.251882  0.732686  0.111690  0.078766
# 4     0.081412  0.184495  0.095043  0.040565  0.884390  0.475880  0.078766
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148209  0.030643  0.919165  0.255171  0.853721  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400263  0.883198  0.111690  0.227765
# 5194  0.009997  0.009929  0.339217  0.947779  0.375754  0.066685  0.057625
# 5195  0.064134  0.104007  0.459271  0.759456  0.951104  0.368111  0.078766
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078766
#
# [5197 rows x 21 columns]

# %%
books.to_csv("books_with_emotions.csv", index=False)
